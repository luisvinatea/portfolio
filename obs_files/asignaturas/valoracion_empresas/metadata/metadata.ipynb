# %%
import os
import logging
import pandas as pd
import openpyxl
import json
from typing import Optional  # Add this import to handle Optional types


logging.basicConfig(level=logging.INFO)

def read_excel_file(file_path: str, sheet_name: Optional[str] = None) -> pd.DataFrame:
    """
    Read an Excel file or a specific sheet into a Pandas DataFrame.
    
    Args:
        file_path (str): The path to the Excel file.
        sheet_name (Optional[str]): The name of the sheet to read. If not provided, the first sheet will be used.
    
    Returns:
        pd.DataFrame: The DataFrame containing the Excel data.
    """
    try:
        return pd.read_excel(file_path, sheet_name=sheet_name, engine='openpyxl')
    except Exception as e:
        logging.error(f"Error reading Excel file: {e}")
        raise

def convert_to_json(df: pd.DataFrame, output_file: str) -> None:
    """
    Convert a Pandas DataFrame to JSON and save it to a file.

    Args:
        df (pd.DataFrame): The DataFrame to convert.
        output_file (str): The path to the output JSON file.
    """
    try:
        json_data = df.to_json(orient='records')
        with open(output_file, 'w') as f:
            json.dump(json_data, f, indent=4)
        logging.info(f"JSON data exported to {output_file}")
    except Exception as e:
        logging.error(f"Error converting to JSON: {e}")

def print_workbook_properties(workbook: openpyxl.Workbook) -> None:
    """
    Print the properties of an openpyxl Workbook.
    """
    properties = workbook.properties
    logging.info(f"Title: {properties.title}")
    logging.info(f"Creator: {properties.creator}")
    logging.info(f"Created: {properties.created}")
    logging.info(f"Modified: {properties.modified}")
    logging.info(f"Last Modified By: {properties.lastModifiedBy}")

def print_sheet_formulas(sheet: openpyxl.worksheet.worksheet.Worksheet) -> None:
    """
    Print the formulas in a given sheet.
    """
    logging.info(f"Formulas in sheet '{sheet.title}':")
    for row in sheet.iter_rows():
        for cell in row:
            if isinstance(cell.value, str) and cell.value.startswith('='):
                logging.info(f"Cell {cell.coordinate} contains the formula: {cell.value}")

def convert_to_numeric(df: pd.DataFrame) -> pd.DataFrame:
    """
    Convert object columns to numeric where possible.
    
    Args:
        df (pd.DataFrame): The input DataFrame.
    
    Returns:
        pd.DataFrame: The DataFrame with object columns converted to numeric.
    """
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = pd.to_numeric(df[col], errors='coerce')
    return df

def main(excel_file_path: Optional[str] = None) -> None:
    """
    Main function to execute the Excel file operations.
    
    Args:
        excel_file_path (Optional[str]): The path to the Excel file. If not provided, a default path will be used.
    """
    if not excel_file_path:
        excel_file_path = 'Pista Evaluación final.xlsx'

    # Load the workbook using openpyxl
    workbook = openpyxl.load_workbook(excel_file_path, data_only=False)

    # Print workbook properties
    print_workbook_properties(workbook)

    # Inspecting WACC and Resultados sheets
    wacc_sheet = workbook['WACC']
    resultado_sheet = workbook['7.Resultado']

    logging.info("\nFormulas in 'WACC' sheet:")
    print_sheet_formulas(wacc_sheet)

    logging.info("\nFormulas in '7.Resultado' sheet:")
    print_sheet_formulas(resultado_sheet)

    # Read and clean the '6. Datos' sheet
    df = read_excel_file(excel_file_path, sheet_name='6. Datos')
    cleaned_df = convert_to_numeric(df)

    # Log data types after conversion
    logging.info("\nData Types After Conversion:")
    logging.info(cleaned_df.dtypes)

    # Log missing values count
    logging.info("\nMissing Values Count:")
    logging.info(cleaned_df.isnull().sum())

    # Convert DataFrame to JSON
    convert_to_json(cleaned_df, 'output.json')

if __name__ == "__main__":
    main()
# Out:
# INFO:root:Title: None
# INFO:root:Creator: Master
# INFO:root:Created: 2015-07-05 20:50:13
# INFO:root:Modified: 2024-09-10 10:41:33
# INFO:root:Last Modified By: Maria Isabel Jara López
# INFO:root:
# Formulas in 'WACC' sheet:
# INFO:root:Formulas in sheet 'WACC':
# INFO:root:Cell F22 contains the formula: =G8*(G16/(G16+G18))+G6*(G18/(G16+G18))
# INFO:root:Cell F23 contains the formula: =G8*(G17/(G17+G18))+G6*(G18/(G17+G18))
# INFO:root:
# Formulas in '7.Resultado' sheet:
# INFO:root:Formulas in sheet '7.Resultado':
# INFO:root:Cell D5 contains the formula: =+C5+(D18*7%)
# INFO:root:Cell D6 contains the formula: =+D83
# INFO:root:Cell D7 contains the formula: =+D82
# INFO:root:Cell C9 contains the formula: =SUM(C5:C8)
# INFO:root:Cell D9 contains the formula: =SUM(D5:D8)
# INFO:root:Cell C15 contains the formula: =SUM(C11:C14)
# INFO:root:Cell D15 contains the formula: =SUM(D11:D14)
# INFO:root:Cell D18 contains the formula: =+(C18*1.06)
# INFO:root:Cell C19 contains the formula: =C18-C20
# INFO:root:Cell D19 contains the formula: =+D18-D20
# INFO:root:Cell C20 contains the formula: =C18*52%
# INFO:root:Cell D20 contains the formula: =D18*52%
# INFO:root:Cell D21 contains the formula: =+D58
# INFO:root:Cell D23 contains the formula: =D63
# INFO:root:Cell D24 contains the formula: =D69
# INFO:root:Cell C25 contains the formula: =+C20-C21-C22-C23-C24
# INFO:root:Cell D25 contains the formula: =+D20-D21-D22-D23-D24
# INFO:root:Cell D26 contains the formula: =+D79
# INFO:root:Cell C27 contains the formula: =+C25-C26
# INFO:root:Cell D27 contains the formula: =+D25-D26
# INFO:root:Cell C28 contains the formula: =+C27*30%
# INFO:root:Cell D28 contains the formula: =+D27*35%
# INFO:root:Cell C29 contains the formula: =+C27-C28
# INFO:root:Cell D29 contains the formula: =+D27-D28
# INFO:root:Cell D32 contains the formula: =+D26
# INFO:root:Cell E32 contains the formula: =+E26
# INFO:root:Cell F32 contains the formula: =+F26
# INFO:root:Cell G32 contains the formula: =+G26
# INFO:root:Cell H32 contains the formula: =+H26
# INFO:root:Cell B33 contains the formula: = Cash-Flow Explotación
# INFO:root:Cell D33 contains the formula: =+D29+D32
# INFO:root:Cell E33 contains the formula: =+E29+E32
# INFO:root:Cell F33 contains the formula: =+F29+F32
# INFO:root:Cell G33 contains the formula: =+G29+G32
# INFO:root:Cell H33 contains the formula: =+H29+H32
# INFO:root:Cell K33 contains the formula: =D18*7%
# INFO:root:Cell L33 contains the formula: =D18*7%
# INFO:root:Cell D35 contains the formula: =+D5-C5
# INFO:root:Cell F35 contains the formula: =+F5-E5
# INFO:root:Cell G35 contains the formula: =+G5-F5
# INFO:root:Cell H35 contains the formula: =+H5-G5
# INFO:root:Cell D36 contains the formula: =+D86
# INFO:root:Cell F36 contains the formula: =+F86
# INFO:root:Cell G36 contains the formula: =+G86
# INFO:root:Cell H36 contains the formula: =+H86
# INFO:root:Cell B38 contains the formula: = CASH-FLOW primera fase
# INFO:root:Cell D38 contains the formula: =+D33-D35-D36
# INFO:root:Cell F38 contains the formula: =+F33-F35-F36
# INFO:root:Cell G38 contains the formula: =+G33-G35-G36
# INFO:root:Cell H38 contains the formula: =+H33-H35-H36
# INFO:root:Cell J38 contains the formula: =+H38*(1+C53)
# INFO:root:Cell H40 contains the formula: =+J38/(C52-C53)
# INFO:root:Cell B42 contains the formula: = CASH-FLOW TOTAL
# INFO:root:Cell D42 contains the formula: =+D38+D40
# INFO:root:Cell E42 contains the formula: =+E38+E40
# INFO:root:Cell F42 contains the formula: =+F38+F40
# INFO:root:Cell G42 contains the formula: =+G38+G40
# INFO:root:Cell H42 contains the formula: =+H38+H40
# INFO:root:Cell D45 contains the formula: =NPV(C52,D42:H42)
# INFO:root:Cell B48 contains the formula: = VALOR ACCIONES
# INFO:root:Cell D48 contains the formula: =+D45-D46+D47
# INFO:root:Cell C52 contains the formula: =+#REF!
# INFO:root:Cell C57 contains the formula: =+C21
# INFO:root:Cell D58 contains the formula: =C59
# INFO:root:Cell C59 contains the formula: =+C57-C58
# INFO:root:Cell C62 contains the formula: =+C23
# INFO:root:Cell D63 contains the formula: =C64
# INFO:root:Cell C64 contains the formula: =+C62-C63
# INFO:root:Cell C68 contains the formula: =+C24
# INFO:root:Cell D69 contains the formula: =C70
# INFO:root:Cell C70 contains the formula: =+C68-C69
# INFO:root:Cell C73 contains the formula: =+C26
# INFO:root:Cell D73 contains the formula: =C26
# INFO:root:Cell E73 contains the formula: =C26
# INFO:root:Cell F73 contains the formula: =C26
# INFO:root:Cell G73 contains the formula: =C26
# INFO:root:Cell H73 contains the formula: =C26
# INFO:root:Cell D74 contains the formula: =+(D18*7%)/10
# INFO:root:Cell E74 contains the formula: =+D74
# INFO:root:Cell F74 contains the formula: =+E74
# INFO:root:Cell G74 contains the formula: =+F74
# INFO:root:Cell H74 contains the formula: =+G74
# INFO:root:Cell E75 contains the formula: =+(E18*7%)/10
# INFO:root:Cell F75 contains the formula: =+E75
# INFO:root:Cell G75 contains the formula: =+F75
# INFO:root:Cell H75 contains the formula: =+G75
# INFO:root:Cell F76 contains the formula: =+(F18*6%)/10
# INFO:root:Cell G76 contains the formula: =+F76
# INFO:root:Cell H76 contains the formula: =+G76
# INFO:root:Cell G77 contains the formula: =+(G18*6%)/10
# INFO:root:Cell H77 contains the formula: =G77
# INFO:root:Cell H78 contains the formula: =(H18*6%)/10
# INFO:root:Cell C79 contains the formula: =SUM(C73:C78)
# INFO:root:Cell D79 contains the formula: =SUM(D73:D78)
# INFO:root:Cell E79 contains the formula: =SUM(E73:E78)
# INFO:root:Cell F79 contains the formula: =SUM(F73:F78)
# INFO:root:Cell G79 contains the formula: =SUM(G73:G78)
# INFO:root:Cell H79 contains the formula: =SUM(H73:H78)
# INFO:root:Cell D82 contains the formula: =+D18*90/360
# INFO:root:Cell E82 contains the formula: =+E18*90/360
# INFO:root:Cell F82 contains the formula: =+F18*90/360
# INFO:root:Cell G82 contains the formula: =+G18*90/360
# INFO:root:Cell H82 contains the formula: =+H18*90/360
# INFO:root:Cell D83 contains the formula: =+D19*80/360
# INFO:root:Cell E83 contains the formula: =+E19*80/360
# INFO:root:Cell F83 contains the formula: =+F19*80/360
# INFO:root:Cell G83 contains the formula: =+G19*80/360
# INFO:root:Cell H83 contains the formula: =+H19*80/360
# INFO:root:Cell C84 contains the formula: =+C14
# INFO:root:Cell D84 contains the formula: =+D19*15/360
# INFO:root:Cell E84 contains the formula: =+E19*15/360
# INFO:root:Cell F84 contains the formula: =+F19*15/360
# INFO:root:Cell G84 contains the formula: =+G19*15/360
# INFO:root:Cell H84 contains the formula: =+H19*15/360
# INFO:root:Cell C85 contains the formula: =C82+C83-C84
# INFO:root:Cell D85 contains the formula: =D82+D83-D84
# INFO:root:Cell E85 contains the formula: =E82+E83-E84
# INFO:root:Cell F85 contains the formula: =F82+F83-F84
# INFO:root:Cell G85 contains the formula: =G82+G83-G84
# INFO:root:Cell H85 contains the formula: =H82+H83-H84
# INFO:root:Cell D86 contains the formula: =+D85-C85
# INFO:root:Cell E86 contains the formula: =+E85-D85
# INFO:root:Cell F86 contains the formula: =+F85-E85
# INFO:root:Cell G86 contains the formula: =+G85-F85
# INFO:root:Cell H86 contains the formula: =+H85-G85
# INFO:root:
# Data Types After Conversion:
# INFO:root:Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3    float64
# Unnamed: 4    float64
# Unnamed: 5    float64
# Unnamed: 6    float64
# Unnamed: 7    float64
# Unnamed: 8    float64
# Unnamed: 9    float64
# dtype: object
# INFO:root:
# Missing Values Count:
# INFO:root:Unnamed: 0    25
# Unnamed: 1    25
# Unnamed: 2     8
# Unnamed: 3    25
# Unnamed: 4    25
# Unnamed: 5    25
# Unnamed: 6    23
# Unnamed: 7    23
# Unnamed: 8    24
# Unnamed: 9    24
# dtype: int64
# INFO:root:JSON data exported to output.json
