# %%
import pandas as pd

# Define the file paths
file_path_1 = '/home/luisvinatea/Projects/data/csv/2023-21 BERAQUA AEREADORES DATASUR ENE.24[48]_sheet1.csv'
file_path_2 = '/home/luisvinatea/Projects/data/csv/COSTOS DE VIDA PRODUCTO_sheet1.csv'

# Load the first CSV file into a pandas DataFrame
try:
    df_1 = pd.read_csv(file_path_1)
    print(f"First file loaded successfully: {file_path_1}")
except FileNotFoundError:
    print(f"File not found: {file_path_1}")
except Exception as e:
    print(f"An error occurred while loading {file_path_1}: {e}")

# Load the second CSV file into a pandas DataFrame
try:
    df_2 = pd.read_csv(file_path_2)
    print(f"Second file loaded successfully: {file_path_2}")
except FileNotFoundError:
    print(f"File not found: {file_path_2}")
except Exception as e:
    print(f"An error occurred while loading {file_path_2}: {e}")

# Inspect the first few rows of each DataFrame
if 'df_1' in locals():
    print("\nFirst CSV file - Head:")
    display(df_1.head())  # Displays the first few rows of the first DataFrame

if 'df_2' in locals():
    print("\nSecond CSV file - Head:")
    display(df_2.head())  # Displays the first few rows of the second DataFrame

# Display basic information about both dataframes
if 'df_1' in locals():
    print("\nFirst CSV file - Info:")
    display(df_1.info())

if 'df_2' in locals():
    print("\nSecond CSV file - Info:")
    display(df_2.info())
# Out:
# First file loaded successfully: /home/luisvinatea/Projects/data/csv/2023-21 BERAQUA AEREADORES DATASUR ENE.24[48]_sheet1.csv
# Second file loaded successfully: /home/luisvinatea/Projects/data/csv/COSTOS DE VIDA PRODUCTO_sheet1.csv
#
# First CSV file - Head:
#          0        1        2        3          4        5         6   7  \
# 0   2023.0      NaN   2022.0      NaN    2021.00      NaN       NaN NaN
# 1  19572.0  14139.0  14140.0  14139.0   14140.00  14139.0  14140.00 NaN
# 2      NaN      NaN      NaN      NaN        NaN      NaN       NaN NaN
# 3  12486.0      NaN      NaN    200.0  192834.93     50.0  24496.35 NaN
# 4   7412.0      NaN      NaN    120.0   54540.00      NaN       NaN NaN
#
#          Author         Creation Date         Modified Date
# 0  jorge bedoya  2024-01-24T10:45:02Z  2024-09-16T14:41:18Z
# 1  jorge bedoya  2024-01-24T10:45:02Z  2024-09-16T14:41:18Z
# 2  jorge bedoya  2024-01-24T10:45:02Z  2024-09-16T14:41:18Z
# ...
